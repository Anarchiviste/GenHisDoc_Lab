# %%
import sys
from pathlib import Path

# Remonte d'un niveau pour accéder au dossier parent (01_code)
sys.path.append(str(Path().resolve().parent))

from utilitaires.yolo import draw_yolo_annotations
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at '/home/lunes/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
imgpath = Path("/home/lunes/Documents/test3.png")
labelpath = Path("/home/lunes/Desktop/geminitest3.txt")
label_map = {
 0: "Illustration",
 1: "Lettrine",
 2: "Estampille",
 3: "Ornementation",
 4: "Table",
}

# La bonne label map pour GenHisDoc Dataset sera dans le data.yaml

# %%
draw_yolo_annotations(image_path=imgpath, label_path=labelpath, label_map=label_map)
# Out:
# <PIL.Image.Image image mode=RGB size=634x474>
