# %%
from pdf2image import convert_from_path

# %%
from pdf2image import convert_from_path

images = convert_from_path('../../Lujes/Recueil_de_tables_astronomiques_publié_[...]Ko_nigliche_Akademie_bd6t5359423b.pdf')
for i in range(len(images)):
    images[i].save(f'../../Lujes/{str(i)}.jpg', 'JPEG')
